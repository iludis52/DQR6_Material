# %%
# --- INSTALLATION DER KERNSYSTEME ---
# LangChain & LangGraph
# %pip install -U langchain langchain-community langgraph

# User Interface (für die interaktiven Web-Oberflächen)
# %pip install gradio

# LLM-Anbindung (OpenAI-Client, wird hier auch für die lokale LM Studio API genutzt)
# %pip install openai

# API-Kommunikation (für direkte HTTP-Anfragen an lokale LLMs)
# %pip install requests


# --- DOKUMENT- UND DATEIVERARBEITUNG ---

# Microsoft Office Automatisierung über die Windows COM-Schnittstelle
# %pip install pywin32

# Extraktion und Metadaten-Schreiben für moderne Word-Dokumente (.docx)
# %pip install python-docx

# Extraktion und Metadaten-Schreiben für moderne PowerPoint-Präsentationen (.pptx)
# %pip install python-pptx

# Extraktion und Metadaten-Schreiben für moderne Excel-Tabellen (.xlsx)
# %pip install openpyxl

# Extraktion aus alten Excel-Tabellen (.xls)
# %pip install xlrd

# Verarbeitung von LibreOffice/OpenOffice-Formaten (.odt, .ods, .odp)
# %pip install odfpy

# PDF-Verarbeitung (Textextraktion, Bildzählung und Metadaten; importiert als 'fitz')
# %pip install PyMuPDF

# Bildverarbeitung (Skalieren, Format-Konvertierung und Basis-Bild-Infos)
# %pip install Pillow

# Lesen und inkrementelles Schreiben von EXIF-Metadaten in Bildern
# %pip install piexif

# Parsing und Extraktion von Text aus HTML- und XML-Dateien
# %pip install beautifulsoup4

# Extraktion von unformatiertem Text aus RTF-Dateien
# %pip install striprtf
