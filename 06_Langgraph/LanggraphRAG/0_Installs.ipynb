# %% [markdown]
# falls auf dem mac gearbeitet wird:
# homebrew installieren:
# a) terminal öffnen und die befehle von b) und c) exakt so eingeben:
# b) /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# c) echo 'eval "$(/opt/homebrew/bin/brew shellenv)"' >> ~/.zprofile
# eval "$(/opt/homebrew/bin/brew shellenv)"
# d) brew --version
# c) brew install graphviz

# %%
# --- INSTALLATION DER KERNSYSTEME ---
# LangChain & LangGraph
# %pip install -U langchain langchain-community langgraph

# Vektor-Datenbank
# %pip install chromadb

# PDF-Verarbeitung
# %pip install pypdf

# LLM-Anbindung (OpenAI & HuggingFace für lokale Embeddings)
# %pip install langchain-openai langchain-huggingface sentence-transformers

# User Interface
# %pip install gradio

# pymupdf als verbesserte library für die pdf-verarbeitung:
# %pip install pymupdf

# word-dokumentverarbeitung
# %pip install langchain-community docx2txt

# NEU: BM25 für Hybrid Search (lexikalischer Retriever)
# %pip install rank_bm25
