# %% [markdown]
# # 2b – Blick in den Index: DB-Rohdaten & Retrieval sichtbar machen
#
# Dieses Notebook **verändert nichts** – es öffnet den fertigen Index nur lesend und macht
# zwei Dinge sichtbar, die sonst verborgen bleiben:
#
# 1. **Wie die Vektor-DB aussieht** – IDs, Metadaten, Vektoren, Klartext
# 2. **Was `similarity_search` tut** – dieselbe Suche, aber mit Distanz-Score pro Treffer
#
# > **Voraussetzung:** Notebook 1 lief, `./chroma_db` existiert. Ein laufender Kernel von
# > Notebook 2 ist *nicht* nötig – hier wird alles selbst geladen.

# %% [markdown]
# ## Minimal-Konfiguration
#
# Nur das, was zum Lesen des Index gebraucht wird. Das Embedding-Modell wählt der
# **Umschalter** (identisch zu Notebook 1) und muss zu dem passen, mit dem der Index
# gebaut wurde – siehe `index_manifest.json`.

# %%
# --- Embedding-Umschalter – identisch zu Notebook 1 --------
EMBEDDING = "bge-m3"                  # "bge-m3" | "e5-instruct" | "e5"

E5_INSTRUCT_TASK = "Given a web search query, retrieve relevant passages that answer the query"

EMBEDDING_PROFILES = {
    "bge-m3": {
        "model": "text-embedding-bge-m3",
        "doc_prefix": "", "query_prefix": "",
    },
    "e5-instruct": {
        "model": "text-embedding-multilingual-e5-large-instruct",
        "doc_prefix": "", "query_prefix": f"Instruct: {E5_INSTRUCT_TASK}\nQuery: ",
    },
    "e5": {
        "model": "text-embedding-multilingual-e5-large",
        "doc_prefix": "passage: ", "query_prefix": "query: ",
    },
}

_ep               = EMBEDDING_PROFILES[EMBEDDING]
EMBEDDING_MODEL   = _ep["model"]
EMBEDDING_PROMPTS = {"doc": _ep["doc_prefix"], "query": _ep["query_prefix"]}

# --- Nur fürs Inspizieren nötig ---
DB_DIR          = "./chroma_db"
COLLECTION_NAME = "langchain"
LM_STUDIO_URL   = "http://localhost:1234/v1"
TOP_K           = 10

# %% [markdown]
# ## Embedding-Modell & Vektordatenbank laden

# %%
import os
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma


class _Prefix:
    """Präfixe aus EMBEDDING_PROMPTS – identisch zu Notebook 1, damit die
    Query-Vektoren genauso entstehen wie die Dokument-Vektoren im Index."""
    _p = EMBEDDING_PROMPTS
    def embed_documents(self, texts):
        return super().embed_documents([self._p["doc"] + t for t in texts])
    def embed_query(self, text):
        return super().embed_query(self._p["query"] + text)


class PrefixOpenAIEmbeddings(_Prefix, OpenAIEmbeddings):
    """Für LM Studio (OpenAI-kompatibel)."""


embeddings = PrefixOpenAIEmbeddings(
    model=EMBEDDING_MODEL,
    api_key="lm-studio",
    base_url=LM_STUDIO_URL,
    check_embedding_ctx_length=False,
)

vectorstore = Chroma(
    collection_name=COLLECTION_NAME,
    persist_directory=DB_DIR,
    embedding_function=embeddings,
)

print(f"✅ Vektordatenbank geladen – {vectorstore._collection.count()} Chunks verfügbar.")
# Out:
# ✅ Vektordatenbank geladen – 5953 Chunks verfügbar.

# %% [markdown]
# ## 1 – Rohblick in die Datenbank
#
# `col.get(...)` holt Datensätze **ohne Suche** direkt aus der Collection. So sieht ein
# gespeicherter Chunk wirklich aus: eine ID, die Metadaten, der Vektor (hier bge-m3 → 1024
# Dimensionen, davon die ersten fünf) und der Klartext.

# %%
col = vectorstore._collection
print("Anzahl Chunks:", col.count())

sample = col.get(limit=5, include=["documents", "metadatas", "embeddings"])

for i in range(len(sample["ids"])):
    vec = sample["embeddings"][i]
    print("\nID:       ", sample["ids"][i])
    print("Metadaten:", sample["metadatas"][i])
    print("Vektor:   ", len(vec), "Dim →", [round(x, 3) for x in vec[:5]], "...")
    print("Text:     ", repr(sample["documents"][i]))
# Out:
# Anzahl Chunks: 5953
#
# ID:        15dbde43-609d-440e-9a27-76710b64e34c
# Metadaten: {'creationdate': '2024-06-04T16:10:15+02:00', 'title': 'Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-Regulierung ist', 'author': 'Bundesministerium für Arbeit und Soziales (BMAS)', 'moddate': '2024-06-06T09:16:15+02:00', 'page': 0, 'creationDate': "D:20240604161015+02'00'", 'keywords': '', 'trapped': '', 'creator': 'Acrobat PDFMaker 24 für Word', 'subject': '', 'file_path': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'modDate': "D:20240606091615+02'00'", 'source': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'format': 'PDF 1.6', 'producer': 'Adobe PDF Library 24.2.23', 'total_pages': 6}
# Vektor:    1024 Dim → [np.float64(-0.048), np.float64(0.007), np.float64(-0.059), np.float64(-0.005), np.float64(-0.021)] ...
# Text:      '#1 – Shortpaper Standards für KI    1 \n \nStandards für KI: Warum der AI Act nur der Anfang der \neuropäischen KI-Regulierung ist \n#1 Shortpaper-Reihe - AI Act und Standardisierung: Wie wir KI-\nSysteme gemeinwohlorientiert gestalten   \nMit der Verabschiedung des AI Acts gewinnt Standardisierung und Normung von KI-Systemen \nzunehmend an Bedeutung. Warum das so ist, was Standards überhaupt sind und wieso sich \ngerade auch die Zivilgesellschaft für diese technische Normung interessieren sollte, ist Inhalt'
#
# ID:        1aea1296-6d32-4a66-b725-bbc775ebb076
# Metadaten: {'moddate': '2024-06-06T09:16:15+02:00', 'page': 0, 'creationDate': "D:20240604161015+02'00'", 'modDate': "D:20240606091615+02'00'", 'trapped': '', 'creator': 'Acrobat PDFMaker 24 für Word', 'file_path': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'keywords': '', 'producer': 'Adobe PDF Library 24.2.23', 'total_pages': 6, 'title': 'Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-Regulierung ist', 'author': 'Bundesministerium für Arbeit und Soziales (BMAS)', 'creationdate': '2024-06-04T16:10:15+02:00', 'subject': '', 'format': 'PDF 1.6', 'source': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf'}
# Vektor:    1024 Dim → [np.float64(-0.05), np.float64(-0.009), np.float64(-0.032), np.float64(0.011), np.float64(-0.032)] ...
# Text:      'gerade auch die Zivilgesellschaft für diese technische Normung interessieren sollte, ist Inhalt \nder Civic Coding x ZVKI-Reihe „AI Act und Standardisierung“ (April 2024 bis September 2024). \nZiel ist, das Bewusstsein zivilgesellschaftlicher Akteur*innen für die Bedeutung von Standards \nfür die KI-Regulierung zu stärken. Dieses Shortpaper fasst die wesentlichen Inhalte der \nAuftaktveranstaltung „Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-'
#
# ID:        7fb7bc8a-a017-4038-92ed-8e81d5e9ec2a
# Metadaten: {'file_path': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'author': 'Bundesministerium für Arbeit und Soziales (BMAS)', 'title': 'Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-Regulierung ist', 'keywords': '', 'source': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'creator': 'Acrobat PDFMaker 24 für Word', 'moddate': '2024-06-06T09:16:15+02:00', 'page': 0, 'total_pages': 6, 'subject': '', 'producer': 'Adobe PDF Library 24.2.23', 'modDate': "D:20240606091615+02'00'", 'format': 'PDF 1.6', 'creationdate': '2024-06-04T16:10:15+02:00', 'creationDate': "D:20240604161015+02'00'", 'trapped': ''}
# Vektor:    1024 Dim → [np.float64(-0.023), np.float64(-0.021), np.float64(-0.039), np.float64(0.006), np.float64(-0.019)] ...
# Text:      'Auftaktveranstaltung „Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-\nRegulierung ist“ zusammen: Was sind Standards? Was sind harmonisierte Normen? Wie \nstehen sie zur KI-Verordnung? Und wie steht es um die zivilgesellschaftliche Beteiligung?  \nInhalt: AI Act, KI-Standards und zivilgesellschaftliche Beteiligung \nAutomatisierte Datenauswertungen in der Medizin, Bild- und Textgeneratoren oder spezialisierte'
#
# ID:        f254a76e-52eb-492d-84ba-72e4fbaf53dc
# Metadaten: {'keywords': '', 'page': 0, 'format': 'PDF 1.6', 'producer': 'Adobe PDF Library 24.2.23', 'subject': '', 'title': 'Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-Regulierung ist', 'moddate': '2024-06-06T09:16:15+02:00', 'source': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'trapped': '', 'file_path': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'creationdate': '2024-06-04T16:10:15+02:00', 'creationDate': "D:20240604161015+02'00'", 'modDate': "D:20240606091615+02'00'", 'total_pages': 6, 'creator': 'Acrobat PDFMaker 24 für Word', 'author': 'Bundesministerium für Arbeit und Soziales (BMAS)'}
# Vektor:    1024 Dim → [np.float64(-0.003), np.float64(0.002), np.float64(-0.033), np.float64(0.039), np.float64(-0.038)] ...
# Text:      'Automatisierte Datenauswertungen in der Medizin, Bild- und Textgeneratoren oder spezialisierte \nChatbots: Systeme Künstlicher Intelligenz (KI-Systeme) sind längst allgegenwärtig und bieten in \nvielen Einsatzbereichen Chancen und Innovationsmöglichkeiten. Mit dem Einsatz von KI-\nSystemen können je nach Kontext und Funktionsweise aber auch Risiken einhergehen.  \nMit der Einführung der KI-Verordnung (KI-VO), auch bekannt als AI Act, versucht die Europäische'
#
# ID:        9f30a5b4-5ec8-4249-bd51-01f1ac8ab943
# Metadaten: {'title': 'Standards für KI: Warum der AI Act nur der Anfang der europäischen KI-Regulierung ist', 'source': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf', 'creationDate': "D:20240604161015+02'00'", 'modDate': "D:20240606091615+02'00'", 'keywords': '', 'author': 'Bundesministerium für Arbeit und Soziales (BMAS)', 'page': 0, 'creator': 'Acrobat PDFMaker 24 für Word', 'subject': '', 'total_pages': 6, 'creationdate': '2024-06-04T16:10:15+02:00', 'producer': 'Adobe PDF Library 24.2.23', 'format': 'PDF 1.6', 'moddate': '2024-06-06T09:16:15+02:00', 'trapped': '', 'file_path': './documents/20240604-Shortpaper_Standards-fuer-KI.pdf'}
# Vektor:    1024 Dim → [np.float64(0.01), np.float64(-0.028), np.float64(-0.023), np.float64(0.048), np.float64(-0.024)] ...
# Text:      'Mit der Einführung der KI-Verordnung (KI-VO), auch bekannt als AI Act, versucht die Europäische \nUnion, den Risiken von Künstlicher Intelligenz angemessen zu begegnen: Dabei wird zwischen KI-\nSystemen und den sog. KI-Modellen mit allgemeinem Verwendungszweck unterschieden. KI-\nSysteme werden nach der KI-VO in verschiedene Risikoklassen mit abgestuften Anforderungen \neingeteilt. So werden bspw. sensible Anwendungsfälle aus dem Arbeitsbereich als „Hochrisiko-KI-'

# %% [markdown]
# ### Und auf der Festplatte?
#
# Die Collection ist keine einzelne Datei. In `chroma.sqlite3` liegen IDs, Text und
# Metadaten (mit `sqlite3` oder „DB Browser for SQLite“ lesbar); die eigentlichen Vektoren
# stecken als binärer HNSW-Index im UUID-Unterordner – bewusst nicht menschenlesbar.

# %%
for root, _, files in os.walk(DB_DIR):
    for f in sorted(files):
        p = os.path.join(root, f)
        print(f"{os.path.getsize(p) // 1024:>7} KB  {p}")
# Out:
#   61856 KB  ./chroma_db/chroma.sqlite3
#   22590 KB  ./chroma_db/ee6b774f-100c-4e84-be23-0a34493e4d8d/data_level0.bin
#       0 KB  ./chroma_db/ee6b774f-100c-4e84-be23-0a34493e4d8d/header.bin
#     490 KB  ./chroma_db/ee6b774f-100c-4e84-be23-0a34493e4d8d/index_metadata.pickle
#      21 KB  ./chroma_db/ee6b774f-100c-4e84-be23-0a34493e4d8d/length.bin
#      47 KB  ./chroma_db/ee6b774f-100c-4e84-be23-0a34493e4d8d/link_lists.bin

# %% [markdown]
# ## 2 – In `similarity_search` hineinschauen
#
# `similarity_search` liefert nur die Chunks. `similarity_search_with_score` liefert
# zusätzlich die **Distanz** – und die macht sichtbar, *warum* gerade diese Treffer kommen.
#
# > Der Wert ist eine Distanz, **kein** Prozent: **kleiner = ähnlicher**. Achte auf den
# > Abstand zwischen Platz 1 und Platz 10 – er zeigt, wie deutlich der Index sich „sicher“ ist.

# %%
frage = "Was ist eine Hochrisiko-Anwendung" #"Was verbietet der AI Act?"

# Stabile Index-Liste (0 … 5960)
all_ids    = col.get(include=[])["ids"]
idx_von_id = {cid: i for i, cid in enumerate(all_ids)}

# Rohe Chroma-Suche: liefert zusätzlich die IDs (die similarity_search verschluckt)
qv  = embeddings.embed_query(frage)
res = col.query(query_embeddings=[qv], n_results=TOP_K,
                include=["documents", "metadatas", "distances"])

print(f"Frage: {frage}\n")
print(f"{'Idx':>5}  {'Distanz':>8}  {'Quelle':<45} {'Seite':>5}  Text")
print("-" * 105)
for cid, doc, meta, dist in zip(res["ids"][0], res["documents"][0],
                                res["metadatas"][0], res["distances"][0]):
    quelle = os.path.basename(meta.get("source", "?"))
    seite  = meta.get("page", 0) + 1
    print(f"{idx_von_id[cid]:>5}  {dist:8.4f}  {quelle[:45]:<45} {seite:>5}  {repr(doc[:100])}...")
# Out:
# Frage: Was ist eine Hochrisiko-Anwendung
#
#   Idx   Distanz  Quelle                                        Seite  Text
# ---------------------------------------------------------------------------------------------------------
#  1898    0.7067  Künstliche Intelligenz im Rahmen des AI Acts    18  'Verkehr gebracht und genutzt werden, unterliegen aber besonders strengen gesetzlichen \nAnforderungen'...
#  1897    0.8449  Künstliche Intelligenz im Rahmen des AI Acts    18  '18 \n \n2.7.2.  Hochrisiko-KI-Systeme \nHochrisiko-KI-Systeme stellen die zweite und umfangreichste Ris'...
#  2978    0.8599  OJ_L_202401689_DE_TXT.pdf                        53  '(1)\nUngeachtet dessen, ob ein KI-System unabhängig von den unter den Buchstaben a und b genannten Pr'...
#   583    0.8643  Guidelines_on_prohibited_artificial_intellige    19  'Bewertung von Risiken in der Kranken- und Lebensversicherung verwendet werden, \nals Hochrisiko-KI-Sy'...
#  1866    0.8703  Künstliche Intelligenz im Rahmen des AI Acts    13  'beeinträchtigen könnten. Besonders Anwendungen in den Bereichen Strafverfolgung, Bildung, \nMigration'...
#  2289    0.8706  OJ_L_202401689_DE_TXT.pdf                        14  'bestimmungsgemäßen Verwendung in explosionsgefährdeten Bereichen, Funkanlagen, Druckgeräte, Sportboo'...
#  2291    0.8743  OJ_L_202401689_DE_TXT.pdf                        14  'Produkte mit mittlerem und hohem Risiko eine Konformitätsbewertung durch Dritte vorgesehen ist.\n(52)'...
#  1829    0.8796  Künstliche Intelligenz im Rahmen des AI Acts     8  'Hochrisiko-KI-Systeme hingegen sind unter bestimmten Voraussetzungen erlaubt, jedoch \nunterliegen di'...
#   298    0.8846  EU-6-001-25-pdf.pdf                              14  'rungsvorschriften eine Konformitätsbewertung durch Dritte für das Inverkehrbringen oder die In\xad\nbetr'...
#   297    0.8966  EU-6-001-25-pdf.pdf                              14  'in der Union haben, wodurch eine mögliche Beschränkung des internationalen Handels so gering \nwie mö'...

# %% [markdown]
# ### Ähnlichkeit der Chunks visualisieren

# %%
import os, numpy as np
import matplotlib.pyplot as plt

# ▼ Welchen Chunk ansehen? Index aus der Tabelle oben (0 … 5960)
CHUNK_INDEX = 1897
#frage       =  "Was verbietet der AI Act?"

all_ids = col.get(include=[])["ids"]
chunk   = col.get(ids=[all_ids[CHUNK_INDEX]],
                  include=["embeddings", "documents", "metadatas"])

chunk_vec = np.array(chunk["embeddings"][0])          # aus der DB (Ansprache des Profils)
frage_vec = np.array(embeddings.embed_query(frage))   # frisch, gleiche Ansprache

cos  = float(frage_vec @ chunk_vec /
             (np.linalg.norm(frage_vec) * np.linalg.norm(chunk_vec)))
dist = 2 - 2 * cos                                    # ≈ Chroma-Distanz (quadr. L2)

meta   = chunk["metadatas"][0]
quelle = os.path.basename(meta.get("source", "?"))
seite  = meta.get("page", 0) + 1

def strich_code(ax, vec, titel):
    lim = np.abs(vec).max()
    ax.imshow(vec.reshape(1, -1), aspect="auto", cmap="coolwarm", vmin=-lim, vmax=lim)
    ax.set_title(titel, fontsize=10, loc="left")
    ax.set_xticks([]); ax.set_yticks([])

fig, axes = plt.subplots(2, 1, figsize=(12, 1.8))
strich_code(axes[0], frage_vec, f'Frage-Vektor  ·  "{frage}"')
strich_code(axes[1], chunk_vec, f"Chunk #{CHUNK_INDEX}  ·  {quelle}  S.{seite}")
fig.suptitle(f"Kosinus-Ähnlichkeit: {cos:.3f}   (Distanz ≈ {dist:.3f})", fontsize=12, y=1.04)
fig.tight_layout(); plt.show()

print(f"\nChunk-Text:\n{chunk['documents'][0]} ")
# Out:
# Chunk-Text:
# 18
#
# 2.7.2.  Hochrisiko-KI-Systeme
# Hochrisiko-KI-Systeme stellen die zweite und umfangreichste Risikokategorie dar, die somit
# das Herzstück des AI Acts bilden. Sie umfassen Anwendungen, deren Verwendung erhebliche
# Auswirkungen auf die Gesundheit, Sicherheit oder Grundrechte von Menschen haben kann,
# ohne dass ein absolutes Verbot notwendig wäre. Diese Systeme dürfen grundsätzlich in
# Verkehr gebracht und genutzt werden, unterliegen aber besonders strengen gesetzlichen
# Anforderungen.67

# %% [markdown]
# ### Den Query-Vektor selbst ansehen
#
# Genau das passiert im Hintergrund vor der Suche: die Frage wird zum Vektor. Der Wrapper
# stellt dabei die im Profil definierte Ansprache voran – bei `bge-m3` keine, bei `e5`
# z. B. `query: ` (deshalb taucht sie im Ergebnis nicht auf).

# %%
qv = embeddings.embed_query(frage)
print("Query-Vektor:", len(qv), "Dimensionen")
print("Erste zehn Werte:", [round(x, 3) for x in qv[:10]])
# Out:
# Query-Vektor: 1024 Dimensionen
# Erste zehn Werte: [-0.013, -0.038, -0.066, 0.046, 0.008, 0.014, 0.012, 0.005, -0.013, -0.014]

# %% [markdown]
# ### Export für die Webseite

# %%
import os, json, random
from collections import defaultdict

random.seed(42)            # reproduzierbar – die Demo bleibt über Läufe stabil
PRO_DOKUMENT  = 60         # Chunks je Dokument (geschichtete Stichprobe)
SOURCE_FILTER = ""         # "" = alle Dokumente; sonst Teilstring des Dateinamens
NACHKOMMA     = 4

all_ids    = col.get(include=[])["ids"]
idx_von_id = {cid: i for i, cid in enumerate(all_ids)}
meta_all   = col.get(include=["metadatas"])

# 1) Chunk-IDs nach Dokument gruppieren
nach_doc = defaultdict(list)
for cid, m in zip(meta_all["ids"], meta_all["metadatas"]):
    if SOURCE_FILTER in m.get("source", ""):
        nach_doc[m["source"]].append(cid)

# 2) aus jedem Dokument gleich viele ziehen (oder alle, wenn weniger)
gewaehlt = []
for quelle, ids in sorted(nach_doc.items()):
    stichprobe = random.sample(ids, min(PRO_DOKUMENT, len(ids)))
    gewaehlt.extend(stichprobe)
    print(f"  {os.path.basename(quelle):40s} {len(stichprobe):4d} / {len(ids)}")

# 3) nur für die Auswahl die Vektoren laden
daten = col.get(ids=gewaehlt, include=["embeddings", "documents", "metadatas"])

chunks = []
for cid, vec, doc, m in zip(daten["ids"], daten["embeddings"],
                            daten["documents"], daten["metadatas"]):
    chunks.append({
        "db_index": idx_von_id[cid],
        "quelle":   os.path.basename(m.get("source", "?")),
        "seite":    m.get("page", 0) + 1,
        "text":     doc,
        "vec":      [round(float(x), NACHKOMMA) for x in vec],
    })

export = {"embedding_model": EMBEDDING_MODEL, "query_prefix": EMBEDDING_PROMPTS["query"],
          "dims": len(chunks[0]["vec"]), "anzahl": len(chunks), "chunks": chunks}

with open("demo_daten.json", "w", encoding="utf-8") as f:
    json.dump(export, f, ensure_ascii=False)

print(f"\n✅ {len(chunks)} Chunks aus {len(nach_doc)} Dokumenten "
      f"→ demo_daten.json ({os.path.getsize('demo_daten.json')/1024/1024:.2f} MB)")
# Out:
#   20240604-Shortpaper_Standards-fuer-KI.pdf   47 / 47
#   2104.05314v2.pdf                           60 / 159
#   EU-6-001-25-pdf.pdf                        60 / 221
#   Guidelines_on_prohibited_artificial_intelligence_practices_established_by_Regulation_EU_20241689_AI_Act_German.PDF   60 / 1361
#   Künstliche Intelligenz im Rahmen des AI Acts der EU.pdf   60 / 255
#   OJ_L_202401689_DE_TXT.pdf                  60 / 1898
#   Regulierung von KI _ Künstliche Intelligenz _ bpb.de.pdf   60 / 76
#   gutachten-datenethikkommission.pdf         60 / 1936
#
# ✅ 467 Chunks aus 8 Dokumenten → demo_daten.json (4.09 MB)
